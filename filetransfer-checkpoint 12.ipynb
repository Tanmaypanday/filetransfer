# %%
import shutil

# Enter the full path of the file you want to transfer
source_file = ("Choose the file path which you transfer")
# Enter the destination folder path
destination_folder = ("Choose the file path where you receive")

# Copy the file to the destination
shutil.copy(source_file, destination_folder)

print("✔ File transferred successfully!")
